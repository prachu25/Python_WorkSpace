# %%
nm = 'takeyouforward'
# print(nm[0])

for i in range(5):
  print(nm[i])
# Out:
# t
# a
# k
# e
# y

# %%
nm[0] = 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3419974775.py in <cell line: 0>()
# ----> 1 nm[0] = 'd'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# Strings are immutable

# %%
language = 'python'
lang = 'java'
code = lang + language
print(code)
# Out:
# javapython

# %% [markdown]
# a new string is created

# %%
a="java"
b="java"
print(id(a))
print(id(b))
print(id(a)==id(b))
# Out:
# 135936680903712
# 135936680903712
# True

# %% [markdown]
# performance optimization

# %%
#reference based storage
x='machine learning'
y=x
print(id(x)==id(y))
# Out:
# True

# %%
s="artificial intelligence"
print(s[3:9])
# Out:
# ificia

# %%
nm="सोहमग्लोबल"
print(nm)
# Out:
# सोहमग्लोबल

# %% [markdown]
# python strings support unicode characters

# %%
nm="SohamGlobal is a company"
print(nm.upper())
print(nm.lower())
print(nm.capitalize())
print(nm.title())
print(nm.swapcase())
# Out:
# SOHAMGLOBAL IS A COMPANY
# sohamglobal is a company
# Sohamglobal is a company
# Sohamglobal Is A Company
# sOHAMgLOBAL IS A COMPANY

# %%
nm = 'Take you Forward'
print(len(nm))
print(max(nm))
print(min(nm))           # space is smallest ASCII 32
print(nm.count('a'))
s="technology is power technology is future java is a technology"
print(s.count('is'))
# Out:
# 16
# y
#
# 2
# 3

# %%
# Searching
print('python'.find('t'))
nm = 'sprintBoot'
print(nm.startswith('sp'))
print(nm.endswith('on'))
# Out:
# 2
# True
# False

# %%
# Checking
print("123".isdigit())
print("abc123".isalpha())
print("abc123".isalnum())
print("soham".isupper())
print("soham".islower())
print("   ".isspace())
# Out:
# True
# False
# True
# False
# True
# True

# %%
s = 'some time you can see'
s = s.replace('can' ,'dont')

print(s)
# Out:
# some time you dont see

# %%
s = "            python           "


print(s.lstrip())
print(s.rstrip())
# Out:
# python
#             python

# %%
s="you will never walk alone"
print(s.split())

film="the matrix,1999,action,wachowskys,keanu reeves,8.9"
print(film.split(","))
# Out:
# ['you', 'will', 'never', 'walk', 'alone']
# ['the matrix', '1999', 'action', 'wachowskys', 'keanu reeves', '8.9']

# %%
print('python'.center(12, "*"))
print('python'.ljust(10,'-'))
print('python'.rjust(10,'-'))
# Out:
# ***python***
# python----
# ----python

# %%
marks = 34
print('my marks are %d' %marks)
print(f'my marks are {marks}')
# Out:
# my marks are 34
# my marks are 34

# %%
s="python"
b=s.encode()
print(b)

print(b.decode())
# Out:
# b'python'
# python
