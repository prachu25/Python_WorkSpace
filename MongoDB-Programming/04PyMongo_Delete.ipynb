# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 30.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 17.8 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient
client = MongoClient(["CONNETCION_SRING"])

# %%
db1 = client["shoppingdb"]
coll_users = db1['users']

# %%
res = coll_users.delete_one({'userid': 'u016'})

if res.deleted_count > 0:
   print("User deleted successfully")
else:
  print("User Not Found")
# Out:
# User deleted successfully
