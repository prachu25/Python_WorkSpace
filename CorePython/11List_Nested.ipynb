# %%
# Nested List

lst=['java','python','spring','pandas',['jon','sam']]
print(lst)
# Out:
# ['java', 'python', 'spring', 'pandas', ['jon', 'sam']]

# %%
lst.append('spark')
print(lst)
# Out:
# ['java', 'python', 'spring', 'pandas', ['jon', 'sam'], 'spark']

# %%
lst[4].append('sachin')
print(lst)
# Out:
# ['java', 'python', 'spring', 'pandas', ['jon', 'sam', 'Rax', 'sachin'], 'spark']

# %%
lst[4].remove('sachin')
print(lst)
# Out:
# ['java', 'python', 'spring', 'pandas', ['jon', 'sam', 'Rax'], 'spark']

# %%
profiles=[
    ['yash','bens','juli'],
    ['core java','python','spring boot'],
    ['9 june','13 january','1 january'],
    [23,10,5],
    ['london','dubai','pune']
]

for items in profiles:
  print(items)
# Out:
# ['yash', 'bens', 'juli']
# ['core java', 'python', 'spring boot']
# ['9 june', '13 january', '1 january']
# [23, 10, 5]
# ['london', 'dubai', 'pune']

# %%
print(profiles[1][2])
# Out:
# spring boot
