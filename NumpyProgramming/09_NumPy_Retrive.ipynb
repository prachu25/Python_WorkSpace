# %%
import numpy

# %%
arr = numpy.array([12,23,24,45,56,67,78,89,90])
print(arr)
# Out:
# [12 23 24 45 56 67 78 89 90]

# %%
print(arr[0])
# Out:
# 12

# %%
print(arr[2:5])
# Out:
# [24 45 56]

# %%
print(arr[-1])
# Out:
# 90

# %%
print(arr[::-1])  # reverse
# Out:
# [90 89 78 67 56 45 24 23 12]

# %%
print(arr[3:])   # after 3 index
print(arr[:4])  # before 4 index
# Out:
# [45 56 67 78 89 90]
# [12 23 24 45]

# %%
lst = [
    [12,23,34,45,56],
    [54,43,32,21,76],
    [21,47,33,69,26]
]

arr = numpy.array(lst)
print(arr)
# Out:
# [[12 23 34 45 56]
#  [54 43 32 21 76]
#  [21 47 33 69 26]]

# %%
print(arr[0][0])
# Out:
# 12

# %%
print(arr[:,:])   # all coloums anad rows
# Out:
# [[12 23 34 45 56]
#  [54 43 32 21 76]
#  [21 47 33 69 26]]

# %%
print(arr[2][3])
# Out:
# 69

# %%
print(arr[1:,:])
# Out:
# [[54 43 32 21 76]
#  [21 47 33 69 26]]
