# %%
import pandas

# %%
dataset_url ="https://raw.githubusercontent.com/sohamglobal/PythonDBWebDSAIML-January2026/refs/heads/main/Pandas/swiggy_orders.csv"

# %%
df = pandas.read_csv(dataset_url)
print(df)
# Out:
#      OrderID      CustomerName  Age  Gender       City  Bill  \
# 0   SWG10001      Aarav Sharma   28    Male     Mumbai   485
# 1   SWG10002       Priya Mehta   34  Female      Delhi   720
# 2   SWG10003       Rohit Verma   22    Male  Bangalore   310
# 3   SWG10004        Sneha Iyer   29  Female    Chennai   890
# 4   SWG10005       Karan Patel   41    Male  Hyderabad  1250
# ..       ...               ...  ...     ...        ...   ...
# 95  SWG10096      Leela Suresh   23  Female    Chennai   290
# 96  SWG10097       Mihir Doshi   35    Male    Kolkata   655
# 97  SWG10098  Nandini Kulkarni   29  Female     Mumbai   905
# 98  SWG10099     Omkar Thakkar   41    Male      Delhi   470
# 99  SWG10100  Preethi Sundaram   27  Female  Bangalore   830
#
#     TimeToDeliver(mins)  Rating
# 0                    32     4.5
# 1                    45     3.8
# 2                    28     4.2
# 3                    55     3.5
# 4                    38     4.7
# ..                  ...     ...
# ...

# %%
url ="https://raw.githubusercontent.com/prachu25/Python_WorkSpace/refs/heads/main/NumpyProgramming/f1_players_200_dataset.csv"

# %%
df = pandas.read_csv(url)
print(df)
# Out:
#      Driver_ID                Name  Age    Country      Team  Championships  \
# 0            1      Mick Magnussen   21     Mexico      Haas              3
# 1            2        Max Sargeant   29     France  Williams              4
# 2            3       Lewis Piastri   20  Australia  Williams              6
# 3            4     George Sargeant   33      Italy  Red Bull              6
# 4            5      Kevin Sargeant   37      Italy  Mercedes              6
# ..         ...                 ...  ...        ...       ...            ...
# 195        196         Mick Guanyu   30     Brazil    Alpine              0
# 196        197   Pierre Hulkenberg   38     France    Alpine              5
# 197        198         Logan Sainz   20     Canada      Haas              0
# 198        199  Fernando Magnussen   33  Australia    Alpine              0
# 199        200        Daniel Perez   31    Germany   Ferrari              7
#
# ...
