# %%
a={1,2,3,4,5}
b={4,5,6,7,8}

# union - combine all values from both sets
res = a.union(b)
print(res)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
# intersection - common values from the sets
res=a.intersection(b)
print(res)
# Out:
# {4, 5}

# %%
# difference - values in the first set but not in second
res=a.difference(b)
print(res)
# Out:
# {1, 2, 3}

# %%
# symmetric difference
res=a.symmetric_difference(b)
print(res)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
amazon={'iPhone','Airpods','MacBook','iPad','Samsung TV','Dell Laptop'}
flipkart={'Samsung TV','iPhone','XBox','PlayStation','Dell Laptop','HP Printer'}
print(amazon)
print(flipkart)
# Out:
# {'Airpods', 'Dell Laptop', 'Samsung TV', 'iPad', 'MacBook', 'iPhone'}
# {'XBox', 'Dell Laptop', 'Samsung TV', 'PlayStation', 'HP Printer', 'iPhone'}

# %%
all = amazon.union(flipkart)
print(all)
# Out:
# {'Samsung TV', 'HP Printer', 'PlayStation', 'iPhone', 'Airpods', 'XBox', 'Dell Laptop', 'iPad', 'MacBook'}

# %% [markdown]
# **show categories exclusively available on amazon**

# %%
# Items that are in the Amazon set but not in the Flipkart set will be returned.

amazon_exclusive = amazon.difference(flipkart)
print(amazon_exclusive)
# Out:
# {'iPad', 'Airpods', 'MacBook'}

# %% [markdown]
# **categories exclusively available on flipkart**

# %%
flipkart_exclusive = flipkart.difference(amazon)
print(flipkart_exclusive)
# Out:
# {'XBox', 'PlayStation', 'HP Printer'}

# %% [markdown]
# **This code will return the unique items from both sets.**

# %%
all_exclusive = amazon.symmetric_difference(flipkart)
print(all_exclusive)
# Out:
# {'HP Printer', 'PlayStation', 'Airpods', 'XBox', 'iPad', 'MacBook'}

# %% [markdown]
# **product categories on both platforms**

# %%
# This code returns the items that are present in both sets (common items).\
common = amazon.intersection(flipkart)
print(common)
# Out:
# {'iPhone', 'Dell Laptop', 'Samsung TV'}

# %% [markdown]
# **Multiple sets**

# %%
microsoft={'Windows','Office','Cloud','XBox','LinkedIn','GitHub','Teams','Search'}
google={'Search','Gmail','Cloud','Drive','Maps','Android'}
apple={'iPhone','Mac','iPad','Cloud','Maps','Music','Watch'}

print(microsoft)
print(google)
print((apple))
# Out:
# {'GitHub', 'Cloud', 'Office', 'Search', 'XBox', 'LinkedIn', 'Teams', 'Windows'}
# {'Search', 'Drive', 'Android', 'Cloud', 'Gmail', 'Maps'}
# {'Mac', 'Watch', 'Maps', 'Cloud', 'iPad', 'iPhone', 'Music'}

# %% [markdown]
# **Intersection &**

# %%
common_services = microsoft & google & apple
print(common_services)
# Out:
# {'Cloud'}

# %% [markdown]
# **Union |**

# %%
common_services = microsoft | google | apple
print(common_services)
# Out:
# {'Watch', 'GitHub', 'Cloud', 'Office', 'iPhone', 'Mac', 'XBox', 'Teams', 'Windows', 'Gmail', 'Maps', 'Music', 'Search', 'Android', 'LinkedIn', 'iPad', 'Drive'}

# %% [markdown]
# **difference -**

# %%
microsoft_exclusive=microsoft - google - apple
print(microsoft_exclusive)

# %% [markdown]
# **symmetric difference ^**

# %%
# Here, ^ means symmetric difference between two sets.
   # It returns the items that are in microsoft OR in google
   # But removes the items that are common in both

microsoft = {"Word", "Excel", "Teams"}
google = {"Docs", "Sheets", "Teams"}

only_exclusive = microsoft ^ google
print(only_exclusive)
# Out:
# {'Sheets', 'Word', 'Excel', 'Docs'}

# %% [markdown]
# **subsetting membership**

# %%
a={1,2,3}
b={1,2,3,4,5}

print(a <= b)            # True
print(a.issubset(b))     # True
print(b.issubset(a))     # False
print(b.issuperset(a))   # True
# Out:
# True
# True
# False
# True
