# %% [markdown]
# **Input output in python**

# %%
nm = input("Enter a name ")
# Out:
# Enter a name jos buttler

# %%
print(f'user name is {nm}')
# Out:
# user name is jos buttler

# %%
n = int(input('Enter a number '))
sq = n*n
print(f'square of {n} is {sq} ')
# Out:
# Enter a number 7
# square of 7 is 49

# %%
x = int(input('Enter a first Number '))
y = int(input('Enter a second Number '))
z = x + y
print(f'the sum of {x} and {y} is {z} ')
# Out:
# Enter a first Number 12
# Enter a second Number 6
# the sum of 12 and 6 is 18

# %%
custnm = input('Enter a customer Name ')
amount = float(input('Enter a purchase amount '))
discount = amount*10/100
netbill = amount - discount

print()
print(f'Customer name is : {custnm}')
print(f'purchase amount is : {amount}')
print(f'Discount : {discount}')
print(f'Net Bill : {netbill}')
# Out:
# Enter a customer Name sam
# Enter a purchase amount 2000
#
# Customer name is : sam
# purchase amount is : 2000.0
# Discount : 200.0
# Net Bill : 1800.0
