# %%
a="python"
b="python"
print(id(a)==id(b))

c=a.upper()
print(id(a)==id(c))
# Out:
# True
# False

# %% [markdown]
# reverse the string

# %%
s="sohamglobal"
rev=""

for ch in s:
  rev=ch+rev

print(rev)
# Out:
# labolgmahos

# %%
s = 'take you forward'

print(s)
print(s[::-1])   # reverse
# Out:
# take you forward
# drawrof uoy ekat

# %%
movie = 'stranger things'

print(movie)
print(movie[3])
print(movie[-1])
print(movie[::-1])
# Out:
# stranger things
# a
# s
# sgniht regnarts

# %%
s = 'madam'
s1 = s[::-1]

if s == s1:
  print('palindrome')
else:
  print('not palindrome')
# Out:
# palindrome

# %%
q = "some time you see"
vowels = "aeiouAEIOU"
count = 0;

for ch in q :
  if ch in vowels:
    count+=1

print(f"number of vowels in the  {q} are {count}")
# Out:
# number of vowels in the  some time you see are 8
