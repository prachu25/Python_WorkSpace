# %%
import pandas

# %%
# This is temp file that stored in google colab
file = pandas.ExcelFile("employees.xlsx")

# %%
df = file.parse("Sheet1")
print(df)
# Out:
#           name gender  age department       post location  salary
# 0     joe root   male   43    finance  executive   london     453
# 1  pat cummins   male   34      admin    manager   sydney    7221

# %%
file2 = pandas.ExcelFile("myshop.xlsx")

# %%
df2 = file2.parse("mobiles")
print(df2)
# Out:
#                   Model Name   Color   RAM    ROM                Processor  \
# 0         Samsung Galaxy S24   Black   8GB  128GB              Exynos 2400
# 1         Samsung Galaxy A55   Green   4GB  512GB              Exynos 1480
# 2            Apple iPhone 15    Gray   6GB   64GB               A16 Bionic
# 3            Apple iPhone 14   Black  12GB  512GB               A15 Bionic
# 4                 OnePlus 12  Silver   8GB   64GB       Snapdragon 8 Gen 3
# 5          OnePlus Nord CE 4    Gold   8GB  256GB       Snapdragon 7 Gen 3
# 6   Xiaomi Redmi Note 13 Pro   Black  12GB  128GB      Snapdragon 7s Gen 2
# 7                  Xiaomi 14   Black   8GB  256GB       Snapdragon 8 Gen 3
# 8            Realme Narzo 70    Blue   6GB  128GB           Dimensity 7050
# 9                Realme GT 6  Silver   4GB  512GB      Snapdragon 8s Gen 3
# 10                  Vivo V30   Black   6GB  512GB       Snapdragon 7 Gen 3
# ...
