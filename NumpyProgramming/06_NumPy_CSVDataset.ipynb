# %%
import numpy

# %%
arr = numpy.genfromtxt("football_players_55.csv", delimiter="," ,dtype=None,encoding=None)
print(arr.shape)
print(arr)
# Out:
# (56, 7)
# [['Player Name' 'Country' 'Club' 'Position' 'Matches' 'Goals' 'Assists']
#  ['Lionel Messi' 'Argentina' 'Inter Milan' 'Defender' '40' '27' '6']
#  ['Cristiano Ronaldo' 'Portugal' 'Chelsea' 'Defender' '21' '16' '17']
#  ['Neymar Jr' 'Brazil' 'Barcelona' 'Defender' '50' '31' '3']
#  ['Kylian Mbappe' 'France' 'Real Madrid' 'Defender' '37' '11' '2']
#  ['Erling Haaland' 'Norway' 'Bayern Munich' 'Goalkeeper' '47' '3' '0']
#  ['Kevin De Bruyne' 'Belgium' 'Arsenal' 'Goalkeeper' '26' '11' '14']
#  ['Harry Kane' 'England' 'Tottenham' 'Forward' '33' '16' '4']
#  ['Mohamed Salah' 'Egypt' 'Liverpool' 'Forward' '38' '5' '18']
#  ['Vinicius Jr' 'Brazil' 'Chelsea' 'Defender' '23' '28' '8']
#  ['Jude Bellingham' 'England' 'Barcelona' 'Midfielder' '47' '25' '9']
#  ['Luka Modric' 'Croatia' 'PSG' 'Defender' '26' '19' '8']
#  ['Robert Lewandowski' 'Poland' 'Juventus' 'Forward' '46' '22' '4']
#  ['Pedri' 'Spain' 'Arsenal' 'Forward' '23' '27' '14']
# ...

# %%
arr = numpy.genfromtxt("https://raw.githubusercontent.com/prachu25/Python_WorkSpace/refs/heads/main/NumpyProgramming/ipl_players_dataset.csv", delimiter="," ,dtype=None,encoding=None)
print(arr.shape)
print(arr)
# Out:
# (51, 9)
# [['Name' 'Age' 'Country' 'Player_Type' 'Price_Crore_INR' 'Runs' 'Wickets'
#   'Average' 'Strike_Rate']
#  ['Virat Kohli' '35' 'India' 'Batter' '21.0' '8004' '4' '38.7' '131.9']
#  ['Rohit Sharma' '38' 'India' 'Batter' '16.3' '6628' '15' '29.7' '131.1']
#  ['MS Dhoni' '44' 'India' 'Wicketkeeper Batter' '12.0' '5243' '0' '39.1'
#   '137.5']
#  ['Hardik Pandya' '32' 'India' 'All-rounder' '15.0' '2525' '64' '28.1'
#   '145.8']
#  ['Ravindra Jadeja' '37' 'India' 'All-rounder' '16.0' '2959' '160' '27.9'
#   '129.8']
#  ['Jasprit Bumrah' '33' 'India' 'Bowler' '12.0' '69' '165' '8.6' '82.1']
#  ['KL Rahul' '34' 'India' 'Wicketkeeper Batter' '17.0' '4683' '0' '46.4'
#   '134.5']
#  ['Suryakumar Yadav' '35' 'India' 'Batter' '16.4' '3594' '0' '33.6'
#   '145.3']
#  ['Shubman Gill' '27' 'India' 'Batter' '18.0' '3216' '0' '37.8' '135.7']
#  ['Rishabh Pant' '29' 'India' 'Wicketkeeper Batter' '16.0' '3284' '0'
#   '34.2' '148.9']
# ...

# %%
arr = numpy.genfromtxt("https://raw.githubusercontent.com/prachu25/Python_WorkSpace/refs/heads/main/NumpyProgramming/f1_players_200_dataset.csv", delimiter="," ,dtype=None,encoding=None)
print(arr.shape)
print(arr)
# Out:
# (201, 13)
# [['Driver_ID' 'Name' 'Age' ... 'Fastest_Laps' 'Pole_Positions'
#   'Salary_Million_USD']
#  ['1' 'Mick Magnussen' '21' ... '52' '81' '43.4']
#  ['2' 'Max Sargeant' '29' ... '2' '55' '37.9']
#  ...
#  ['198' 'Logan Sainz' '20' ... '33' '35' '37.8']
#  ['199' 'Fernando Magnussen' '33' ... '7' '22' '6.4']
#  ['200' 'Daniel Perez' '31' ... '9' '41' '29.0']]
