# %%
friends = []
cho = ''

while cho.lower()!='no':
  nm = input('Enter friend name: ')
  friends.append(nm)
  cho = input('Do you want to add more friends? (yes/no): ')
else:
  print(friends)
# Out:
# Enter friend name: will
# Do you want to add more friends? (yes/no): yes
# Enter friend name: nancy
# Do you want to add more friends? (yes/no): yes
# Enter friend name: mike
# Do you want to add more friends? (yes/no): yes
# Enter friend name: 11
# Do you want to add more friends? (yes/no): no
# ['will', 'nancy', 'mike', '11']

# %%
s = input('Enter a name : ')

if s in friends:
  print('friend found')
else:
  print('friend not found..added')
  friends.append(s)

print(friends)
# Out:
# Enter a name : mike
# friend found
# ['will', 'nancy', 'mike', '11', 'johnthon', 'stev']

# %%
password = 'liverpool'
user_pass = ""

while user_pass!= password :
  user_pass = input('Enter Password: ')


  if user_pass == password:
    print('welcome to python world')
  else:
    print('wrong, try again...')
# Out:
# Enter Password: rba
# wrong, try again...
# Enter Password: python
# wrong, try again...
# Enter Password: liverpool
# welcome to python world
