# %%
# Tuples

empty = ()
print(type(empty))
# Out:
# <class 'tuple'>

# %%
co_ord = (10,20)
print(type(co_ord))
# Out:
# <class 'tuple'>

# %%
# single tuple
tup = (2,)            # single tuple create like this
print(type(tup))
# Out:
# <class 'tuple'>

# %%
mixed=(9,'mike',68.14,True)
print(mixed)
print(type(mixed))
# Out:
# (9, 'mike', 68.14, True)
# <class 'tuple'>

# %%
nested=((1,2),(3,4))
print(nested)
print(type(nested))
# Out:
# ((1, 2), (3, 4))
# <class 'tuple'>

# %%
t = (45,'Rohit',['opener','Mumbai Indians'],'India')
print(t)

print(type(t))
t[2].append('pull shot')

print(t)
t.append('Mumbai ch Raja')    # Tuple → immutable → append not allowed
# Out:
# (45, 'Rohit', ['opener', 'Mumbai Indians'], 'India')
# <class 'tuple'>
# (45, 'Rohit', ['opener', 'Mumbai Indians', 'pull shot'], 'India')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1616669018.py in <cell line: 0>()
#       6
#       7 print(t)
# ----> 8 t.append('Mumbai ch Raja')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# List → mutable → append allowed
#
# Tuple → immutable → append not allowed

# %%
lst = [1,2,3]
print(lst)

lst.append(4)      # List → mutable → append allowed
print(lst)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
tup=(1726,'sam','saving','dadar mumbai',43100.50)
print(len(tup))
# Out:
# 5

# %%
tup=('sooru','saving','dadar mumbai')
print(max(tup))
print(min(tup))
# Out:
# sooru
# dadar mumbai

# %%
t = (1,2,9,0,-4)
print(max(t))
print(min(t))

print()

for i in t:
  print(i)
# Out:
# 9
# -4
#
# 1
# 2
# 9
# 0
# -4

# %%
t=(5,1,2,4,2,7,3)
print(sorted(t))
# Out:
# [1, 2, 2, 3, 4, 5, 7]

# %%
t1=(1,2,3)
t2=(4,5,6)
t3=t1+t2
print(t3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# **Storage comparison**

# %%
import sys

lst=[1,2,3,4,5]
tup=(1,2,3,4,5)

print(sys.getsizeof(lst))
print(sys.getsizeof(tup))
# Out:
# 104
# 80

# %%
tup=('harsh','ishan','mike','will','ishan','ishan','ishan')
print(tup.count('ishan'))
print(tup.index('mike'))   # index no
# Out:
# 4
# 2
