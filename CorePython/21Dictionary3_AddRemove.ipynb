# %%
tech={'os':'windows','language':'java','database':'oracle'}
print(tech)
# Out:
# {'os': 'windows', 'language': 'java', 'database': 'oracle'}

# %%
tech['cloud'] = 'aws'
print(tech)
# Out:
# {'os': 'windows', 'language': 'java', 'database': 'oracle', 'cloud': 'aws'}

# %%
tech['database'] = 'mongodb'
print(tech)
# Out:
# {'os': 'windows', 'language': 'java', 'database': 'mongodb', 'cloud': 'aws'}

# %%
tech.update({'framework':'springboot','aiplatform':'deepseeks'})
print(tech)
# Out:
# {'os': 'windows', 'language': 'java', 'database': 'mongodb', 'cloud': 'aws', 'framework': 'springboot', 'aiplatform': 'deepseeks'}

# %%
tech.update({"framework":'Hibernate'})
print(tech)
# Out:
# {'os': 'windows', 'language': 'java', 'database': 'mongodb', 'cloud': 'aws', 'framework': 'Hibernate', 'aiplatform': 'deepseeks'}

# %%
tech['experience']=5
print(tech)
# Out:
# {'os': 'windows', 'language': 'java', 'database': 'mongodb', 'cloud': 'aws', 'framework': 'Hibernate', 'aiplatform': 'deepseeks', 'experience': 5}

# %%
tech['experience']+=2
print(tech)
# Out:
# {'os': 'windows', 'language': 'java', 'database': 'mongodb', 'cloud': 'aws', 'framework': 'Hibernate', 'aiplatform': 'deepseeks', 'experience': 7}

# %% [markdown]
# **remove**

# %%
del tech['database']    # 'database': 'mongodb'  delete the key database

# %%
print(tech)
# Out:
# {'language': 'java', 'cloud': 'aws', 'framework': 'Hibernate', 'aiplatform': 'deepseeks', 'experience': 7}

# %%
print(tech.pop('language'))   # delete and print **pop**
# Out:
# java

# %%
print(tech)
# Out:
# {'cloud': 'aws', 'framework': 'Hibernate', 'aiplatform': 'deepseeks', 'experience': 7}

# %% [markdown]
# **clear()** is a built-in dictionary method in Python that removes all key–value pairs from the dictionary and makes it empty.

# %%
tech.clear()  # delete all key value pairs

# %%
print(tech)
# Out:
# {}

# %%
tech["language"]="python"
tech["framework"]="django"
tech["database"]="mysql"
print(tech)
# Out:
# {'language': 'python', 'framework': 'django', 'database': 'mysql'}
