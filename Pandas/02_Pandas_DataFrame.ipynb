# %%
import pandas

# %%
# Double dim data
films = [
    ['the matrix', 'pk','dil se'],
    [1999, 2014,1998],
    ['action','comedy','romance'],
    ['english','hindi','hindi'],
    ['Keanu reeves','amir khan','shah rukh khan'],
    [8.9,9.8,7.6]
]

# %%
df = pandas.DataFrame(films)
print(df)
# Out:
#               0          1               2
# 0    the matrix         pk          dil se
# 1          1999       2014            1998
# 2        action     comedy         romance
# 3       english      hindi           hindi
# 4  Keanu reeves  amir khan  shah rukh khan
# 5           8.9        9.8             7.6

# %%
rows = ['filmname','year','genre','language','actor','rating ']
cols = ['Harshu' ,'Mike' ,'Will']
df = pandas.DataFrame(films,rows,cols)
print(df)
# Out:
#                 Harshu       Mike            Will
# filmname    the matrix         pk          dil se
# year              1999       2014            1998
# genre           action     comedy         romance
# language       english      hindi           hindi
# actor     Keanu reeves  amir khan  shah rukh khan
# rating             8.9        9.8             7.6

# %%
# que - show the fav movies of Will?
print(df['Will'])
# Out:
# filmname            dil se
# year                  1998
# genre              romance
# language             hindi
# actor       shah rukh khan
# rating                 7.6
# Name: Will, dtype: object

# %%
# print the will fav film name
print(df['Will']['filmname'])
# Out:
# dil se
