# %% [markdown]
# **Series**

# %%
import pandas

# %%
s1 = pandas.Series([12,22,33,44,65])

# %%
print(s1)
# Out:
# 0    12
# 1    22
# 2    33
# 3    44
# 4    65
# dtype: int64

# %%
s2 = pandas.Series(["java","springBoot","mongoDB","SQL","Azure"])
print(s2)
# Out:
# 0          java
# 1    springBoot
# 2       mongoDB
# 3           SQL
# 4         Azure
# dtype: object

# %% [markdown]
# Label

# %%
s3 = pandas.Series(['java','azure','mySQL'],
                   index =['language','cloud','database'])

# %%
print(s3)
# Out:
# language     java
# cloud       azure
# database    mySQL
# dtype: object

# %%
s4 = pandas.Series([98.99,98.88,56.77],
                   index = ['joe','mike','eleven'])
print(s4)
# Out:
# joe       98.99
# mike      98.88
# eleven    56.77
# dtype: float64

# %% [markdown]
# Diffrent data types strored in series-> it considred as "OBJECT"

# %%
s5 = pandas.Series(['joe',22,99.87,True])
print(s5.dtype)
# Out:
# object
