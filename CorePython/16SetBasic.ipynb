# %%
tech={'java','python','jpa','spring','pandas','openai','spring','jpa'}
print(tech)
print(type(tech))
# Out:
# {'pandas', 'python', 'spring', 'java', 'jpa', 'openai'}
# <class 'set'>

# %%
s = {12,33,4,55}
print(s)
print(type(s))
# Out:
# {33, 12, 4, 55}
# <class 'set'>

# %%
empty=set()
print(type(empty))
# Out:
# <class 'set'>

# %%
mixed={9,"Mike",68.14,True}
mixed.append(78)            # in set -> there is no append keyword use ** add

print(mixed)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3673842956.py in <cell line: 0>()
#       1 mixed={9,"Mike",68.14,True}
# ----> 2 mixed.append(78)
#       3
#       4 print(mixed)
#
# AttributeError: 'set' object has no attribute 'append'

# %%
mixed={9,"Mike",68.14,True}
mixed.add(78)                # to insert element-> .add()

print(mixed)
# Out:
# {'Mike', True, 68.14, 9, 78}

# %%
print(mixed[2])     # Indexing not Allowed in Set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1416467525.py in <cell line: 0>()
# ----> 1 print(mixed[2])
#
# TypeError: 'set' object is not subscriptable

# %%
mixed.remove(True)
print(mixed)
# Out:
# {'Mike', 68.14, 9, 78}

# %%
tech={'java','python','jpa','spring','pandas','openai','spring','jpa'}
print(len(tech))
print(max(tech))
print(min(tech))
# Out:
# 6
# spring
# java
