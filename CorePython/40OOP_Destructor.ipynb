# %% [markdown]
# **Destructor (__del __)**
# A destructor is a special method that runs automatically when an object is destroyed.

# %%
class Demo:
    def __del__(self):
        print("Object destroyed")

d = Demo()
del d   # Destructor runs here


# del is a keyword used to delete an object, variable, or element from memory.
# Out:
# Object destroyed
