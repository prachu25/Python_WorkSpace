# %%
import numpy
import pandas

# %%
df = pandas.DataFrame(numpy.random.rand(10,4), columns = ['mumbai','chennai','kolkata','hydrabad'])
print(df)
# Out:
#      mumbai   chennai   kolkata  hydrabad
# 0  0.333310  0.170764  0.780523  0.282452
# 1  0.203612  0.116450  0.886824  0.432131
# 2  0.516215  0.365790  0.839973  0.384691
# 3  0.308488  0.385567  0.045606  0.439658
# 4  0.932778  0.996976  0.132782  0.030050
# 5  0.606505  0.116128  0.974077  0.433659
# 6  0.487648  0.655942  0.803522  0.725691
# 7  0.424926  0.959831  0.021742  0.491466
# 8  0.114774  0.697449  0.835839  0.351425
# 9  0.571857  0.544442  0.334362  0.684313
