# %% [markdown]
# **Creating byte variable and store byte data**

# %%
b1=bytes([97,98,99,100,101])
print(b1)
print(type(b1))
# Out:
# b'abcde'
# <class 'bytes'>

# %% [markdown]
# UTF-8 ek encoding format hai jo text ko numbers (bytes) me convert karta hai.
#
# 'Hello' = normal string (text)
#
# bytes('Hello', encoding='utf-8') = text → bytes me convert

# %%
b2=bytes('Hello',encoding='utf-8')
print(b2)
print(type(b2))
# Out:
# b'Hello'
# <class 'bytes'>

# %%
m = b'python'
print(m)
print(type(m))
# Out:
# b'python'
# <class 'bytes'>

# %%
b4=bytes(5)
print(b4)
# Out:
# b'\x00\x00\x00\x00\x00'

# %%
b = bytes.fromhex('6869746d616e')
print(b)
# Out:
# b'hitman'

# %%
print(b.decode())
# Out:
# hitman

# %%
data = b'ABC'
print(len(data))
# Out:
# 3

# %%
data = b'Mumbai'
print(len(data))
# Out:
# 6

# %%
newdata = data+b' Indians '
print(newdata)
# Out:
# b'Mumbai Indians '

# %%
print(newdata*3)
# Out:
# b'Mumbai Indians Mumbai Indians Mumbai Indians '
