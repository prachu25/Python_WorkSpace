# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 27.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 16.4 MB/s eta 0:00:00
# ...

# %%
import numpy
from pymongo import MongoClient

# %%
client = MongoClient("CONNECTION STRING")

# %%
db = client["spiderdb"]
fcoll= db["films"]

# %%
for doc in fcoll.find():
  print(doc)
# Out:
# {'_id': 101, 'filmnm': 'the matrix', 'releaseyr': 1993, 'genre': 'action', 'actor': 'keanu reeves', 'imdbrating': 8.7}
# {'_id': 105, 'filmnm': 'Shershaaha', 'main charter': 'Vikram Bharta', 'genre': 'War,Romance', 'imdbrating': 8.5}
# {'_id': ObjectId('684354d0888745feb1934fd9'), 'id': 104, 'filmnm': 'KGF', 'main charter': 'Rocky', 'genre': 'Action,crime', 'imdbrating': 8.2, 'music': 'Ravi Basrur'}
# {'_id': 102, 'filmnm': 'Kantra', 'main char': 'shiva', 'imdbrating': 8.3, 'genre': 'mystry'}
# {'_id': 106, 'filmnm': 'social Network', 'imdbrating': 6.7, 'genre': 'networking', 'actor': 'Jesse Eisenberg'}
# {'_id': 107, 'filmnm': 'RRR', 'imdbrating': 8, 'genre': 'action'}
# {'_id': 108, 'filmnm': 'Pushpa', 'main char': 'Pushpa Raj', 'imdbrating': 9, 'genre': 'action'}
# {'_id': 109, 'filmnm': 'Titanic', 'main char': 'Jack Dawson', 'imdbrating': 7.9, 'genre': 'romance'}
# {'_id': 110, 'filmnm': 'The Notebook', 'main char': 'Noah', 'imdbrating': 7.8, 'genre': 'romance'}
# ...

# %%
cursor = fcoll.find()
docs = list(cursor)
data = [(f['filmnm'],f['genre'],f['imdbrating']) for f in docs]

for i in data:
  print(i)
# Out:
# ('the matrix', 'action', 8.7)
# ('Shershaaha', 'War,Romance', 8.5)
# ('KGF', 'Action,crime', 8.2)
# ('Kantra', 'mystry', 8.3)
# ('social Network', 'networking', 6.7)
# ('RRR', 'action', 8)
# ('Pushpa', 'action', 9)
# ('Titanic', 'romance', 7.9)
# ('The Notebook', 'romance', 7.8)
# ('Hacker', 'hacking', 9)

# %%
arr = numpy.array(data)
print(arr.shape)
print(arr)
# Out:
# (10, 3)
# [['the matrix' 'action' '8.7']
#  ['Shershaaha' 'War,Romance' '8.5']
#  ['KGF' 'Action,crime' '8.2']
#  ['Kantra' 'mystry' '8.3']
#  ['social Network' 'networking' '6.7']
#  ['RRR' 'action' '8']
#  ['Pushpa' 'action' '9']
#  ['Titanic' 'romance' '7.9']
#  ['The Notebook' 'romance' '7.8']
#  ['Hacker' 'hacking' '9']]
