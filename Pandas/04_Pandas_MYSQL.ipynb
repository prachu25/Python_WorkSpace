# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.2.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.2.0

# %%
import pandas
import pymysql

# %%
con = pymysql.connect(
    host=('HOST_NAME'),
    port=('PORT_NUMBER'),
    user=('USER_NAME'),
    password=('PASSWORD'),
    database=('DATABASE_NAME')
    )
print('connected successfully')
# Out:
# connected successfully

# %%
                  # ( Query , which connection through)
df = pandas.read_sql("select * from accounts",con)
print(df)
# Out:
# /tmp/ipykernel_19234/4102783207.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pandas.read_sql("select * from accounts",con)
#     accno                   accnm  acctype   balance
# 0       1                Joe Root   saving   52000.0
# 1       2              Ben Stokes  current   61000.0
# 2       3          James Anderson    fixed   45000.0
# 3       4            Stuart Broad      ppf  140000.0
# 4       5             Jos Buttler   saving   38000.0
# 5       6            Jofra Archer  current   64000.0
# 6       7            David Warner    fixed   55000.0
# 7       8             Steve Smith   saving   73000.0
# 8       9             Pat Cummins      ppf   47000.0
# 9      10          Mitchell Starc  current   68000.0
# 10     11           Glenn Maxwell   saving   42000.0
# 11     12      Marnus Labuschagne    fixed   51000.0
# 12     13             Aaron Finch      ppf   36000.0
# 13     14             Travis Head  current   62000.0
# 14     15           Cameron Green   saving   49000.0
# 15     16              Harry Kane    fixed   75000.0
# 16     17         Raheem Sterling  current   33000.0
# 17     18         Marcus Rashford   saving   58000.0
# 18     19         Kevin De Bruyne      ppf   72000.0
# 19     20           Mohamed Salah  current   67000.0
# 20     21          Erling Haaland   saving   74000.0
# 21     22         Bruno Fernandes    fixed   43000.0
# 22     23             Bukayo Saka      ppf   52000.0
# 23     24              Phil Foden   saving   61000.0
# 24     25             Declan Rice  current   48000.0
# 25     26           Jack Grealish    fixed   69000.0
# 26     27        Jordan Henderson   saving   35000.0
# 27     28             Reece James      ppf   57000.0
# 28     29         Virgil van Dijk  current   71000.0
# 29     30          Alisson Becker   saving   46000.0
# 30     31          Bernardo Silva    fixed   53000.0
# 31     32           Son Heung-min      ppf   60000.0
# 32     33         Martin Odegaard   saving   41000.0
# 33     34           Gabriel Jesus  current   65000.0
# 34     35               Luke Shaw    fixed   37000.0
# 35     36               Ben White   saving   54000.0
# 36     37           Ollie Watkins      ppf   62000.0
# 37     38          James Maddison  current   44000.0
# 38     39  Trent Alexander-Arnold   saving   73000.0
# 39     40         Kalvin Phillips    fixed   59000.0
# 40     41             Eoin Morgan   saving   30000.0
# 41     42              Sam Curran  current   56000.0
# 42     43               Mark Wood    fixed   47000.0
# 43     44              Alex Carey      ppf   52000.0
# 44     45          Josh Hazlewood   saving   66000.0
# 45     46             Nathan Lyon  current   39000.0
# 46     47            Chris Woakes    fixed   61000.0
# 47     48          Mitchell Marsh   saving   58000.0
# 48     49   Dominic Calvert-Lewin      ppf   43000.0
# 49     50             John Stones  current   72000.0
# 50     51                    Mike   saving   25000.0

# %%
df =pandas.read_sql("select * from doctors" ,con)
print(df)
# Out:
# /tmp/ipykernel_19234/2568017365.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df =pandas.read_sql("select * from doctors" ,con)
#    doctor_id   doctor_name specialization  experience_years
# 0          1     Dr. Smith   Cardiologist                15
# 1          2   Dr. Johnson    Neurologist                12
# 2          3  Dr. Williams     Orthopedic                10
# 3          4     Dr. Brown  Dermatologist                 8
# 4          5    Dr. Taylor   Pediatrician                 6

# %%
con.close()
